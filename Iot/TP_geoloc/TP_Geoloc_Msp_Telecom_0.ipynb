# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from geopy.distance import vincenty

# %%
# load train and test data
df_mess_train = pd.read_csv('mess_train_list.csv') # train set
df_mess_test = pd.read_csv('mess_test_list.csv') # test set
pos_train = pd.read_csv('pos_train_list.csv') # position associated to train set

# %%
len(df_mess_train["messid"].unique())
# Out:
# 6068

# %%
df_mess_train.shape
# Out:
# (39250, 8)

# %%
df_mess_train.head()
# Out:
#                      messid  bsid       did  nseq   rssi       time_ux  \
# 0  573bf1d9864fce1a9af8c5c9  2841  473335.0   0.5 -121.5  1.463546e+12
# 1  573bf1d9864fce1a9af8c5c9  3526  473335.0   2.0 -125.0  1.463546e+12
# 2  573bf3533e952e19126b256a  2605  473335.0   1.0 -134.0  1.463547e+12
# 3  573c0cd0f0fe6e735a699b93  2610  473953.0   2.0 -132.0  1.463553e+12
# 4  573c0cd0f0fe6e735a699b93  3574  473953.0   1.0 -120.0  1.463553e+12
#
#       bs_lat      bs_lng
# 0  39.617794 -104.954917
# 1  39.677251 -104.952721
# 2  39.612745 -105.008827
# 3  39.797969 -105.073460
# 4  39.723151 -104.956216

# %%
df_mess_train[["messid", "nseq", "rssi", "time_ux"]].groupby(["messid"]).mean()
# Out:
#                               nseq        rssi       time_ux
# messid
# 573bf1d9864fce1a9af8c5c9  1.250000 -123.250000  1.463546e+12
# 573bf3533e952e19126b256a  1.000000 -134.000000  1.463547e+12
# 573c0cd0f0fe6e735a699b93  1.666667 -117.333333  1.463553e+12
# 573c1272f0fe6e735a6cb8bd  1.000000 -127.416667  1.463555e+12
# 573c8ea8864fce1a9a5fbf7a  1.214286 -125.996032  1.463586e+12
# 573c9148864fce1a9a616174  1.090909 -125.363636  1.463587e+12
# 573c939cf0fe6e735ac36de1  0.916667 -125.453704  1.463588e+12
# 573c9667f0fe6e735ac51891  1.000000 -136.000000  1.463588e+12
# 573c9892f0fe6e735ac6603f  1.200000 -121.740000  1.463589e+12
# 573c9d7b3e952e1912d9f567  1.750000 -126.750000  1.463590e+12
# 573cbc43f0fe6e735adabf38  1.000000 -123.000000  1.463598e+12
# 573cbc7ff0fe6e735adadeab  0.750000 -131.000000  1.463598e+12
# 573cc276864fce1a9a7dd272  0.000000 -127.000000  1.463600e+12
# 573cc3e1864fce1a9a7e8cac  1.500000 -122.500000  1.463600e+12
# ...

# %%
len(df_mess_train["did"].unique())
# Out:
# 113

# %%
df_mess_train[["did", "bsid"]].groupby(["did"]).count()
# Out:
#            bsid
# did
# 473288.0    343
# 473335.0    459
# 473368.0     24
# 473401.0     19
# 473438.0     11
# 473502.0     14
# 473507.0    527
# 473512.0     22
# 473683.0    126
# 473796.0   1474
# 473805.0     66
# 473864.0     26
# 473871.0    139
# 473892.0     78
# 473897.0     10
# 473899.0   1234
# 473902.0    430
# 473953.0    378
# 474126.0    315
# 474176.0    818
# 474181.0    240
# 474192.0   2971
# 476123.0    224
# 476140.0    341
# 476161.0     38
# 476185.0   6653
# 476197.0      1
# 476207.0    328
# 476210.0     34
# 476212.0    477
# ...         ...
# 476607.0    126
# 476609.0   1722
# 476610.0     17
# 476611.0     26
# 476615.0     22
# 476826.0     76
# 476828.0     16
# 476829.0   4104
# 476830.0     86
# 476833.0    358
# 476835.0    604
# 476836.0     24
# 476841.0     32
# 476852.0    528
# 476853.0    166
# 476861.0     83
# 476868.0      5
# 476883.0     19
# 476884.0     40
# 476885.0    273
# 476887.0     15
# 476888.0    136
# 476889.0    900
# ...

# %%
df_mess_train[["messid", "bsid"]].groupby(["messid"]).count().max()
# Out:
# bsid    106
# dtype: int64

# %%
df_mess_train.describe()
# Out:
#                bsid           did          nseq          rssi       time_ux  \
# count  39250.000000  3.925000e+04  39250.000000  39250.000000  3.925000e+04
# mean    4533.774752  4.835932e+05      1.043541   -125.863580  1.473368e+12
# std     2570.495638  9.893140e+04      0.563540      9.226500  5.506910e+09
# min      879.000000  4.732880e+05      0.000000   -155.000000  1.463546e+12
# 25%     2790.000000  4.761230e+05      1.000000   -132.500000  1.468410e+12
# 50%     3559.000000  4.763150e+05      1.000000   -127.333333  1.473444e+12
# 75%     7456.000000  4.766090e+05      1.500000   -121.000000  1.479118e+12
# max    11951.000000  1.747448e+06      2.000000    -64.000000  1.481143e+12
#
#              bs_lat        bs_lng
# count  39250.000000  39250.000000
# mean      42.554998   -100.969685
# std        7.722787     11.522732
# min       36.053394   -107.463146
# 25%       39.747448   -105.074287
# 50%       39.793585   -105.043685
# 75%       39.838740   -104.998429
# ...

# %%
pos_train.head()
# Out:
#          lat         lng
# 0  39.606690 -104.958490
# 1  39.606690 -104.958490
# 2  39.637741 -104.958554
# 3  39.730417 -104.968940
# 4  39.730417 -104.968940

# %%
pos_train.describe()
# Out:
#                 lat           lng
# count  39250.000000  39250.000000
# mean      39.783333   -105.056343
# std        0.206262      0.162954
# min       35.770683   -107.630679
# 25%       39.708599   -105.060463
# 50%       39.776882   -105.039440
# 75%       39.805279   -105.018730
# max       43.140387   -102.094289

# %%
pos_train.groupby(["lat", "lng"]).count()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
listOfBs = np.union1d(np.unique(df_mess_train['bsid']), np.unique(df_mess_test['bsid'])) # determine all Base stations that received at least 1 message

# %%
len(listOfBs)
# Out:
# 259

# %%
# Feature Matrix construction 

def feat_mat_const(df_mess_train, listOfBs):
    mean = df_mess_train[["messid", "nseq", "rssi", "time_ux"]].groupby(["messid"]).mean()
    countBSID = df_mess_train[["messid", "bsid"]].groupby(["messid"]).count()
    df = pd.concat(mean, )
    return df_feat

# %%
# ground truth construction

def ground_truth_const(df_mess_train, pos_train):


    
    return ground_truth_lat, ground_truth_lng

# %%
df_feat = feat_mat_const(df_mess_train, listOfBs)
df_feat.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-248bf2d5c1d8> in <module>
# ----> 1 df_feat = feat_mat_const(df_mess_train, listOfBs)
#       2 df_feat.head()
#
# <ipython-input-16-a35160c0e600> in feat_mat_const(df_mess_train, listOfBs)
#       4     mean = df_mess_train[["messid", "nseq", "rssi", "time_ux"]].groupby(["messid"]).mean()
#       5     countBSID = df_mess_train[["messid", "bsid"]].groupby(["messid"]).count()
# ----> 6     df = pd.concat(mean, )
#       7     return df_feat
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     223                        keys=keys, levels=levels, names=names,
#     224                        verify_integrity=verify_integrity,
# --> 225                        copy=copy, sort=sort)
# ...

# %%
ground_truth_lat, ground_truth_lng = ground_truth_const(df_mess_train, pos_train)
ground_truth_lat.shape

# %%
# Validation

# %%
def regressor_and_predict(df_feat, ground_truth_lat, ground_truth_lng, df_test):
    
    # train regressor and make prediction in the train set
    # Input: df_feat: feature matrix used to train regressor
    #        ground_truth_lat: df_feat associated latitude
    #        ground_truth_lng: df_feat associated longitude
    #        df_test: data frame used for prediction
    # Output: y_pred_lat, y_pred_lng

    
    return y_pred_lat, y_pred_lng

# %%
# Make regressor and prediction using the train set

# %%
y_pred_lat, y_pred_lng = regressor_and_predict(df_feat, ground_truth_lat, ground_truth_lng, df_feat)

# %%
# Cross validation

# %%
# Evaluate result

# %%
def vincenty_vec(vec_coord):
    vin_vec_dist = np.zeros(vec_coord.shape[0])
    if vec_coord.shape[1] !=  4:
        print('ERROR: Bad number of columns (shall be = 4)')
    else:
        vin_vec_dist = [vincenty(vec_coord[m,0:2],vec_coord[m,2:]).meters for m in range(vec_coord.shape[0])]
    return vin_vec_dist

# %%
# evaluate distance error for each predicted point
def Eval_geoloc(y_train_lat , y_train_lng, y_pred_lat, y_pred_lng):
    vec_coord = np.array([y_train_lat , y_train_lng, y_pred_lat, y_pred_lng])
    err_vec = vincenty_vec(np.transpose(vec_coord))
    
    return err_vec

# %%
err_vec = Eval_geoloc(ground_truth_lat , ground_truth_lng, y_pred_lat, y_pred_lng)

# %%
# Plot error distribution

# %%
values, base = np.histogram(err_vec, bins=50000)
cumulative = np.cumsum(values) 
plt.figure();
plt.plot(base[:-1]/1000, cumulative / np.float(np.sum(values))  * 100.0, c='blue')
plt.grid(); plt.xlabel('Distance Error (km)'); plt.ylabel('Cum proba (%)'); plt.axis([0, 30, 0, 100]); 
plt.title('Error Cumulative Probability'); plt.legend( ["Opt LLR", "LLR 95", "LLR 99"])

# %%
# Error criterion

np.percentile(err_vec, 80)

# %%
# Construct test prediction
