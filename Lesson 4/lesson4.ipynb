# %% [markdown]
# ## Import

# %%
import requests
from termcolor import colored
from bs4 import BeautifulSoup
import pandas as pd
import re

# %%
#target dataframe
DF = pd.DataFrame( columns=["version","year", "km", "price", "pro"])

# %%
#handle url function
def _handle_request_result_and_build_soup(page_url):
  request_result = requests.get(page_url)
  if request_result.status_code == 200:
    html_doc =  request_result.text
    soup = BeautifulSoup(html_doc,"html.parser")
    #get_Div(soup)
    #r = requests.get(website_, headers={'Accept': 'application/json'})
    #dftable = pd.read_html(html_doc, attrs = {'class': 'adContainer'})
    return soup

# %%
#get all announces
def get_Divs(soup):      
    return soup.findAll("div", {'class' : 'adLineContainer' })

# %% [markdown]
# ## def functions

# %%
# create pd series
def getRow(div):
#     print(div.find("h3").findAll("span")[1].text)
#     print(div.find("div", {"class" : "fieldYear"}).text)
#     #print(re.sub('[\s+]', '', div.find("div", {"class" : "fieldMileage"}).text))
#     print(re.match(r"\d+", re.sub('[\s+]', '', div.find("div", {"class" : "fieldMileage"}).text)).group(0))
#     #print(div.find("nobr").text)
#     print(re.match(r"\d+", re.sub('[\s+]', '', div.find("nobr").text)).group(0))
#     print(div.find("div", {"class" : "typeSellerGaranty"}).find("p").text)
        
    try:
        version = div.find("h3").findAll("span")[1].text
        annee = div.find("div", {"class" : "fieldYear"}).text
        km = re.match(r"\d+", re.sub('[\s+]', '', div.find("div", {"class" : "fieldMileage"}).text)).group(0)
        prix = re.match(r"\d+", re.sub('[\s+]', '', div.find("nobr").text)).group(0)
        match = re.match("Professionnel", div.find("div", {"class" : "typeSellerGaranty"}).find("p").text )
        pro = 1 if match else 0
    except AttributeError:
        return None 

    dfDiv = pd.DataFrame([[version, annee, km, prix, pro]], columns=["version","year", "km", "price", "pro"])
    return dfDiv

# %% [markdown]
# ## build target dataframe

# %%
def buildDF(df):
    for i in range(1,20):
        website_ = "https://www.lacentrale.fr/listing?regions=FR-IDF%2CFR-NAQ%2CFR-PAC&makesModelsCommercialNames=RENAULT%3AZOE&page="+str(i)
        page = _handle_request_result_and_build_soup(website_)
        divs = get_Divs(page)
        for div in divs:
            try:
                df = pd.concat([df, getRow(div)], ignore_index=True) 
            except TypeError:
                continue
    return df

# %%
DF = buildDF(DF)

# %%
DF.head()
# Out:
#                     version  year     km  price pro
# 0     Q90 ZEN CHARGE RAPIDE  2016  34734   9850   1
# 1  Q90 INTENS CHARGE RAPIDE  2014  31137  10270   1
# 2                   Q90 ZEN  2014  32564  10360   1
# 3     Q90 ZEN CHARGE RAPIDE  2016  23984  12080   1
# 4    Q90 LIFE CHARGE RAPIDE  2015  54661   8010   1

# %%
DF.shape
# Out:
# (293, 5)

# %%
DF["year"] = pd.to_numeric(DF["year"])
DF["km"] = pd.to_numeric(DF["km"])
DF["price"] = pd.to_numeric(DF["price"])

# %%
DF["year"].min()
# Out:
# 2012

# %%
DF["year"].max()
# Out:
# 2019

# %%
DF["version"].unique()
# Out:
# array(['Q90 ZEN CHARGE RAPIDE', 'Q90 INTENS CHARGE RAPIDE', 'Q90 ZEN',
#        'Q90 LIFE CHARGE RAPIDE', '(2) R90 INTENS', 'Q90 LIFE',
#        'INTENS CHARGE RAPIDE', 'LIFE', 'Q90 INTENS', 'INTENS',
#        'R110 INTENS', 'R90 ZEN', 'R90 INTENS',
#        'Q90 LIFE CHARGE RAPIDE TYPE 2',
#        '(2) Q90 LIFE CHARGE RAPIDE GAMME 2017',
#        '(2) Q90 INTENS CHARGE RAPIDE GAMME 2017',
#        'Q90 INTENS CHARGE RAPIDE TYPE 2', '(2) R90 ZEN',
#        'LIFE CHARGE RAPIDE', 'Q90 ZEN CHARGE RAPIDE TYPE 2',
#        'R90 INTENS TYPE 2', 'R90 INTENS GAMME 2017', 'INTENS 5P',
#        'LIFE R75', 'LIFE CHARGE RAPIDE GAMME 2017 5P', 'R75 LIFE',
#        'LIFE CHARGE RAPIDE 5P', '(2) R110 INTENS', 'R90 LIFE TYPE 2',
#        'ZEN CHARGE RAPIDE', '(2) R75 LIFE', 'LIFE 5P',
#        '(2) Q90 ZEN CHARGE RAPIDE GAMME 2017', '(2) R90 STAR WARS',
#        'LIFE CHARGE RAPIDE GAMME 2017', 'ZEN R90 2018', 'INTENS R90',
#        'R75 LIFE GAMME 2017', 'INTENS GAMME 2017'], dtype=object)

# %% [markdown]
# ## build "average rating" dataframe by version and year

# %%
DFcote = pd.DataFrame(columns=["version", "year", "mean"])
for version in DF["version"].unique():
    for annee in range(DF["year"].min(), DF["year"].max() + 1):
        site = "https://www.lacentrale.fr/cote-auto-renault-zoe-"+version.lower().replace(" ", "+")+"-"+str(annee)+".html"
        request_result = requests.get(site)
        if request_result.status_code == 200:
            html_doc =  request_result.text
            soup = BeautifulSoup(html_doc,"html.parser")
            try:
                cote = re.sub('[\s+]', '', soup.find("span", {"class" : "jsRefinedQuot"}).text)
                DFcote = pd.concat([DFcote, pd.DataFrame([[version, annee, cote]], columns=["version", "year", "mean"])], ignore_index=True) 
            except AttributeError:
                print(site)
                continue
# Out:
# https://www.lacentrale.fr/cote-auto-renault-zoe-q90+zen+charge+rapide-2018.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-q90+zen+charge+rapide-2019.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-q90+intens+charge+rapide-2018.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-q90+intens+charge+rapide-2019.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-q90+zen-2012.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-q90+zen-2018.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-q90+zen-2019.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-q90+life+charge+rapide-2018.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-q90+life+charge+rapide-2019.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-(2)+r90+intens-2012.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-(2)+r90+intens-2013.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-(2)+r90+intens-2014.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-(2)+r90+intens-2019.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-q90+life-2012.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-q90+life-2018.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-q90+life-2019.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-intens+charge+rapide-2012.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-intens+charge+rapide-2013.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-intens+charge+rapide-2014.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-intens+charge+rapide-2015.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-intens+charge+rapide-2016.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-intens+charge+rapide-2017.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-intens+charge+rapide-2018.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-intens+charge+rapide-2019.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-life-2012.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-life-2013.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-life-2014.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-life-2015.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-life-2016.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-life-2017.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-life-2018.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-life-2019.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-q90+intens-2012.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-q90+intens-2018.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-q90+intens-2019.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-intens-2012.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-intens-2013.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-intens-2014.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-intens-2015.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-intens-2016.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-intens-2017.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-intens-2018.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-intens-2019.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-r110+intens-2012.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-r110+intens-2013.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-r110+intens-2014.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-r110+intens-2015.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-r110+intens-2016.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-r110+intens-2017.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-r110+intens-2018.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-r110+intens-2019.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-r90+zen-2012.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-r90+zen-2013.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-r90+zen-2014.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-r90+zen-2015.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-r90+zen-2016.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-r90+zen-2017.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-r90+zen-2018.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-r90+zen-2019.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-r90+intens-2012.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-r90+intens-2013.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-r90+intens-2014.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-r90+intens-2015.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-r90+intens-2016.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-
2019.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-zen+r90+2018-2012.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-zen+r90+2018-2013.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-zen+r90+2018-2014.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-zen+r90+2018-2015.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-zen+r90+2018-2016.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-zen+r90+2018-2017.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-zen+r90+2018-2018.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-zen+r90+2018-2019.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-intens+r90-2012.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-intens+r90-2013.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-intens+r90-2014.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-intens+r90-2015.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-intens+r90-2016.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-intens+r90-2017.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-intens+r90-2018.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-intens+r90-2019.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-r75+life+gamme+2017-2012.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-r75+life+gamme+2017-2013.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-r75+life+gamme+2017-2019.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-intens+gamme+2017-2012.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-intens+gamme+2017-2013.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-intens+gamme+2017-2014.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-intens+gamme+2017-2015.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-intens+gamme+2017-2016.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-intens+gamme+2017-2017.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-intens+gamme+2017-2018.html
# https://www.lacentrale.fr/cote-auto-renault-zoe-intens+gamme+2017-2019.html

# %%
display(DFcote.head())
DFcote.shape
# Out:
#                  version  year   mean
# 0  Q90 ZEN CHARGE RAPIDE  2012   8185
# 1  Q90 ZEN CHARGE RAPIDE  2013   9203
# 2  Q90 ZEN CHARGE RAPIDE  2014  11036
# 3  Q90 ZEN CHARGE RAPIDE  2015  12009
# 4  Q90 ZEN CHARGE RAPIDE  2016  12174
# (109, 3)

# %% [markdown]
# ## update target df

# %%
ratings = []
for i in DF.index:
    #print(DFcote["mean"][DFcote.loc[(DFcote['version'] == DF["version"][i]) & (DFcote['year'] == DF["year"][i])].index].values)
    rating = DFcote["mean"][DFcote.loc[(DFcote['version'] == DF["version"][i]) & (DFcote['year'] == DF["year"][i])].index].values
    
    if not rating.size == 0:
        ratings.append(rating[0])
    else :
        ratings.append(None)
#         print (rating[0])
#         DF.insert(i, "rating", rating[0])

# %%
len(ratings)
# Out:
# 293

# %%
if "rating" in DF.columns:
    DF = DF.drop(["rating"], axis=1)
DF.insert(5, "rating", ratings)

# %%
DF.head()
# Out:
#                     version  year     km  price pro rating
# 0     Q90 ZEN CHARGE RAPIDE  2016  34734   9850   1  12174
# 1  Q90 INTENS CHARGE RAPIDE  2014  31137  10270   1   9625
# 2                   Q90 ZEN  2014  32564  10360   1  10809
# 3     Q90 ZEN CHARGE RAPIDE  2016  23984  12080   1  12174
# 4    Q90 LIFE CHARGE RAPIDE  2015  54661   8010   1  10646

# %%
DF["rating"] = pd.to_numeric(DF["rating"])
DF
# Out:
#                       version  year      km  price pro   rating
# 0       Q90 ZEN CHARGE RAPIDE  2016   34734   9850   1  12174.0
# 1    Q90 INTENS CHARGE RAPIDE  2014   31137  10270   1   9625.0
# 2                     Q90 ZEN  2014   32564  10360   1  10809.0
# 3       Q90 ZEN CHARGE RAPIDE  2016   23984  12080   1  12174.0
# 4      Q90 LIFE CHARGE RAPIDE  2015   54661   8010   1  10646.0
# 5              (2) R90 INTENS  2019    6826  18980   1      NaN
# 6                    Q90 LIFE  2016   17282  10190   1  12321.0
# 7                    Q90 LIFE  2014   17705  10960   1   9090.0
# 8                    Q90 LIFE  2016   18995  10030   1  12321.0
# 9      Q90 LIFE CHARGE RAPIDE  2014   12767   8800   1  10066.0
# 10             (2) R90 INTENS  2018    9550  16570   1  15042.0
# 11                   Q90 LIFE  2014   36278   9860   1   9090.0
# 12     Q90 LIFE CHARGE RAPIDE  2015   27637   9130   1  10646.0
# 13                   Q90 LIFE  2014   18134  10330   1   9090.0
# 14                   Q90 LIFE  2016   66675   7670   1  12321.0
# 15       INTENS CHARGE RAPIDE  2014   21971  12150   1      NaN
# 16                   Q90 LIFE  2014   18765  10480   1   9090.0
# 17                       LIFE  2013   17544   8380   1      NaN
# 18                   Q90 LIFE  2016   17175  10310   1  12321.0
# 19                   Q90 LIFE  2016   26697  10100   1  12321.0
# 20                    Q90 ZEN  2015   10237  11550   1  10109.0
# 21                    Q90 ZEN  2014   17944  11380   1  10809.0
# 22     Q90 LIFE CHARGE RAPIDE  2016   65199   8660   1  11236.0
# 23     Q90 LIFE CHARGE RAPIDE  2014   15561   8540   1  10066.0
# 24                   Q90 LIFE  2014   64673   8590   1   9090.0
# 25     Q90 LIFE CHARGE RAPIDE  2015   11180  11190   1  10646.0
# 26                   Q90 LIFE  2014   18609  10580   1   9090.0
# 27                   Q90 LIFE  2016   16767  10020   1  12321.0
# 28                    Q90 ZEN  2016   64676   8680   1  13174.0
# 29     Q90 LIFE CHARGE RAPIDE  2014   26829  10420   1  10066.0
# ..                        ...   ...     ...    ...  ..      ...
# 263                    INTENS  2014   42449  12900   1      NaN
# 264    Q90 LIFE CHARGE RAPIDE  2014   62259   8380   1  10066.0
# 265                    INTENS  2014   44425  10770   1      NaN
# 266               (2) R90 ZEN  2019     123  26180   1      NaN
# 267                    INTENS  2015   58209  10280   1      NaN
# 268                  Q90 LIFE  2015   21264  12240   1   9945.0
# 269     Q90 ZEN CHARGE RAPIDE  2014   45625   9860   1  11036.0
# 270              ZEN R90 2018  2019     120  27700   1      NaN
# 271  Q90 INTENS CHARGE RAPIDE  2016   18056  11710   1  13274.0
# 272                  Q90 LIFE  2014    6351  10980   1   9090.0
# 273                R90 INTENS  2017    5382  21040   1      NaN
# 274     R90 INTENS GAMME 2017  2017    6100  24270   1  14195.0
# 275                  Q90 LIFE  2014   49601  13050   1   9090.0
# 276  Q90 INTENS CHARGE RAPIDE  2015   55333   8860   1  10624.0
# 277        LIFE CHARGE RAPIDE  2016   12913  10160   1      NaN
# 278      INTENS CHARGE RAPIDE  2013   23941  12480   1      NaN
# 279                INTENS R90  2017     121  28850   1      NaN
# 280       R75 LIFE GAMME 2017  2019    4680  23880   1      NaN
# 281                  Q90 LIFE  2014   52140   9600   1   9090.0
# 282              (2) R75 LIFE  2017   10900  16880   1  13254.0
# 283  Q90 INTENS CHARGE RAPIDE  2013   32618  10600   1   9929.0
# 284                      LIFE  2015   32700  10350   1      NaN
# 285               (2) R90 ZEN  2019    5700  17770   1      NaN
# 286                   R90 ZEN  2019    6720  18250   1      NaN
# 287         INTENS GAMME 2017  2018   12532  17880   1      NaN
# 288               (2) R90 ZEN  2017    5900  22400   1  13399.0
# 289        LIFE CHARGE RAPIDE  2014  105423   8590   1      NaN
# 290    Q90 LIFE CHARGE RAPIDE  2015   16197  10590   1  10646.0
# 291                      LIFE  2014   67645  11120   1      NaN
# 292                  R75 LIFE  2017      92  24240   1      NaN
#
# [293 rows x 6 columns]

# %% [markdown]
# ## covert to csv

# %%
DFcote.to_csv("coteMoyenne.csv", ",")
DF.to_csv("zoe.csv", ",")
